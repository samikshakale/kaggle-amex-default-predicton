# %% [markdown]
# # Installation + Import

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (23.1.2)

# %%
# !python3 -m pip install numpy
# !python3 -m pip install pandas
# !python3 -m pip install scikit-learn==1.0.2 #version copatible with imblearn library
# !python3 -m pip install xgboost
# !python3 -m pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (1.24.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn==1.0.2
#   Downloading scikit_learn-1.0.2-cp38-cp38-macosx_10_13_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 524.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.14.6 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from scikit-learn==1.0.2) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from scikit-learn==1.0.2) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from scikit-learn==1.0.2) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from scikit-learn==1.0.2) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed scikit-learn-1.0.2
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (1.7.6)
# Requirement already satisfied: numpy in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from xgboost) (1.24.4)
# Requirement already satisfied: scipy in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from xgboost) (1.10.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from imbalanced-learn->imblearn) (1.24.4)
# Requirement already satisfied: scipy>=1.3.2 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from imbalanced-learn->imblearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from imbalanced-learn->imblearn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/samikshakale/Library/Python/3.8/lib/python/site-packages (from imbalanced-learn->imblearn) (3.1.0)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc

# Data Precessing 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

# Model
import xgboost as xgb 
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Training Data Preprocessing
# Read in the training data and perform preprocessing

# %%
Train_df = pd.read_feather('amexfeather/train_data.ftr')

# %%
Train_df = Train_df.groupby('customer_ID').tail(1)

# %% [markdown]
# ## Dropping Null Columns
# Drop all columns with null ratio greater than 0.7

# %%
Null_Check = pd.DataFrame({'Columns':Train_df.columns,
                           'Null Ratio':Train_df.isna().sum().values / len(Train_df)}).sort_values(by = ['Null Ratio'], ascending = False)

# %%
for i in np.linspace(0,1, 11).round(1):
    print(i, len(Null_Check[Null_Check['Null Ratio'] > i]))
    
Drop_Columns = Null_Check[Null_Check['Null Ratio'] > 0.7]['Columns']

# %%
Train_df = Train_df.drop(columns = Drop_Columns)

# %% [markdown]
# ## PCA
# Perform PCA on data with number of components equal to 6

# %%
# Prepare for a PCA 
Master_df = Train_df[['customer_ID','target']].reset_index(drop = True)

# Categorial
PCA_Cat = Train_df.select_dtypes(include='category').reset_index(drop = True)

for i in PCA_Cat.columns:
    PCA_Cat[i].fillna(PCA_Cat[i].quantile(.5), inplace = True)
    
PCA_Cat = pd.get_dummies(PCA_Cat, drop_first= True)

# Numeric and Normalize
PCA_Numeric = Train_df.select_dtypes(include=['float16']).reset_index(drop = True)

for i in PCA_Numeric.columns:
    PCA_Numeric[i] = PCA_Numeric[i].astype('float64')
    PCA_Numeric[i] = PCA_Numeric[i].fillna(PCA_Numeric[i].mean())

PCA_Numeric = pd.DataFrame(StandardScaler().fit_transform(PCA_Numeric), columns = PCA_Numeric.columns)
    
# Concat
PCA_df = pd.concat([PCA_Cat, PCA_Numeric], axis = 1)

# PCA
PCA_Model = PCA(n_components=6, random_state=0)
Temp = pd.DataFrame(PCA_Model.fit_transform(PCA_df))
Master_df = pd.concat([Master_df.iloc[:, :2], Temp], axis = 1)

# %% [markdown]
# ## SMOTE Oversampling
# Resample so that the counts of target=0 and target=1 are the same

# %%
sm = SMOTE(random_state=42)
X, y = sm.fit_resample(Master_df.iloc[:,2:], Master_df['target'])

# %% [markdown]
# # Amex Competition Metric
# Define the method that the competition uses to score predictions

# %%
def amex_metric(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:

    def top_four_percent_captured(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        df = (pd.concat([y_true, y_pred], axis='columns')
              .sort_values('prediction', ascending=False))
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        four_pct_cutoff = int(0.04 * df['weight'].sum())
        df['weight_cumsum'] = df['weight'].cumsum()
        df_cutoff = df.loc[df['weight_cumsum'] <= four_pct_cutoff]
        return (df_cutoff['target'] == 1).sum() / (df['target'] == 1).sum()
        
    def weighted_gini(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        df = (pd.concat([y_true, y_pred], axis='columns')
              .sort_values('prediction', ascending=False))
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        df['random'] = (df['weight'] / df['weight'].sum()).cumsum()
        total_pos = (df['target'] * df['weight']).sum()
        df['cum_pos_found'] = (df['target'] * df['weight']).cumsum()
        df['lorentz'] = df['cum_pos_found'] / total_pos
        df['gini'] = (df['lorentz'] - df['random']) * df['weight']
        return df['gini'].sum()

    def normalized_weighted_gini(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        y_true_pred = y_true.rename(columns={'target': 'prediction'})
        return weighted_gini(y_true, y_pred) / weighted_gini(y_true, y_true_pred)

    g = normalized_weighted_gini(y_true, y_pred)
    d = top_four_percent_captured(y_true, y_pred)

    return 0.5 * (g + d)

# %% [markdown]
# # Model
# Define XBG model using best parameters determined by the EDA notebook and fit it to the training data

# %%
best_parameters = {'max_depth': 12, 'min_child_weight': 7, 'eta': 0.1, 'objective': 'binary:logistic', 'tree_method': 'gpu_hist', 'eval_metric': 'rmsle'}

XGB_Model = xgb.XGBClassifier(**best_parameters,
                              verbosity = 1,
                              n_jobs = -1).fit(X, y)

# %%
del Train_df, PCA_Numeric, PCA_Cat, PCA_df, Master_df, Temp
gc.collect()

# %% [markdown]
# # Test Data Preprocessing
# Read in the test data and perform preprocessing

# %%
Test_df = pd.read_feather('amexfeather/test_data.ftr')

# %%
Test_df = Test_df.groupby('customer_ID').tail(1)

# %% [markdown]
# ## Dropping Null Columns

# %%
Test_df = Test_df.drop(columns = Drop_Columns)

# %% [markdown]
# ## PCA

# %%
# Prepare for a PCA 
Master_df = Test_df[['customer_ID']].reset_index(drop = True)

# Categorial
PCA_Cat = Test_df.select_dtypes(include='category').reset_index(drop = True)

for i in PCA_Cat.columns:
    PCA_Cat[i].fillna(PCA_Cat[i].quantile(.5), inplace = True)
    
PCA_Cat = pd.get_dummies(PCA_Cat, drop_first= True)

# Numeric and Normalize
PCA_Numeric = Test_df.select_dtypes(include=['float16']).reset_index(drop = True)

for i in PCA_Numeric.columns:
    PCA_Numeric[i] = PCA_Numeric[i].astype('float64')
    PCA_Numeric[i] = PCA_Numeric[i].fillna(PCA_Numeric[i].mean())

PCA_Numeric = pd.DataFrame(StandardScaler().fit_transform(PCA_Numeric), columns = PCA_Numeric.columns)
    
# Concat
PCA_df = pd.concat([PCA_Cat, PCA_Numeric], axis = 1)

# PCA
PCA_Model = PCA(n_components=6, random_state=0)
Temp = pd.DataFrame(PCA_Model.fit_transform(PCA_df))
Master_df = pd.concat([Master_df.iloc[:, :2], Temp], axis = 1)

# %% [markdown]
# # Prediction
# Use XGB model to predict probabilities for each customer in the test dataset

# %%
prediction = pd.DataFrame({'customer_ID':Master_df['customer_ID'],
                           'prediction':XGB_Model.predict_proba(Master_df.iloc[:,1:])[:, 1]})

del PCA_Numeric, PCA_Cat, PCA_df, Master_df, Temp
gc.collect()

# %%
prediction.to_csv('submission.csv', index=False)
